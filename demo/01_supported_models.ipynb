# %%
from dotenv import load_dotenv
from langchain_anthropic import ChatAnthropic
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_openai import ChatOpenAI
from rich import print as rprint

load_dotenv()

# %%
gemini = ChatGoogleGenerativeAI(model="gemini-2.5-pro", vertexai=True)
rprint(gemini)

# %%
gpt = ChatOpenAI(model="gpt-5")
rprint(gpt)

# %%
claude = ChatAnthropic(model_name="claude-sonnet-4-5")  # pyright: ignore
rprint(claude)

# %% [markdown]
# ### Source? -> [Here](https://github.com/anomalyco/models.dev)
